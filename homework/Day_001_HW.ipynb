# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 203.194
# The Mean absolute error is 11.420

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Competitions: Google Landmark Retrieval 2020
#
# ## 1 . 你選的這組資料為何重要
#
# 此為GOOLE發起的挑戰，雖然圖片搜尋的特徵選取的分類上已經錯誤率連年降低，尤其是靜態的物體(標誌，地標等)，但仍然有許多可以進步之處，現今如果要搜尋一個特定的物件，如富士山，東京鐵塔等特定物體仍會有需多誤判，依然需要很多文字檢索的輔助才能做到。
#
# ## 2 . 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# "Google Landmarks Dataset v2 - A Large-Scale Benchmark for Instance-Level Recognition and Retrieval", T. Weyand, A. Araujo, B. Cao and J. Sim, Proc. CVPR'20
#
# ## 3 . 蒐集而來的資料型態為何
#
# 皆為非結構化:地標image和地標描述text
#
# ## 4 . 這組資料想解決的問題如何評估
#
# Submissions are evaluated according to mean Average Precision
#
# ![google評估式](https://github.com/waitingSu/ML100Days/blob/master/google_evaluator.PNG?raw=true)
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ## 1 . 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 尋找各縣市的叫車熱點，如個不同時段(天氣，日子)與地點(車站或學校)關聯。
# 目標在於減少司機搜尋時間提升載客率，減少客人呼叫後的等車時間。
#
# ## 2 . 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 乘客乘車的歷史數據資料(車隊叫車資料庫) and 當時空的地區氣象資料，以及人事行政日曆(判斷是否放假)。
#
# ## 3 . 蒐集而來的資料型態為何
#
# 結構化:乘客乘坐地點(經緯數值)，人數(數值),氣象數據(降雨機率，經緯，天氣)，人事行政日曆(國定假日or颱風假:數值)
#
# ## 4 . 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 司機使用系統後，是否能於指定時間內成功載到特定的1~N位乘客的機率。
#
# 可以用MSE進行評估至少載到一位的平均損失時間。
